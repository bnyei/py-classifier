# %%
openDoc = open('db/Final sheph db.csv', 'r')
mainRef = openDoc.readlines()

bswDoc = open('db/bsw.csv', 'w')
bswDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
bswDoc.write('\n')

organaDoc = open('db/organa.csv', 'w')
organaDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
organaDoc.write('\n')

evangDoc = open('db/evang.csv', 'w')
evangDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
evangDoc.write('\n')

coordiDoc = open('db/coordi.csv', 'w')
coordiDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
coordiDoc.write('\n')

usherDoc = open('db/ushering.csv', 'w')
usherDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
usherDoc.write('\n')

welfDoc = open('db/welfare.csv', 'w')
welfDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
welfDoc.write('\n')

prayerDoc = open('db/prayer.csv', 'w')
prayerDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
prayerDoc.write('\n')

rgcDoc = open('db/rgc.csv', 'w')
rgcDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
rgcDoc.write('\n')

choirDoc = open('db/choir.csv', 'w')
choirDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
choirDoc.write('\n')

vohDoc = open('db/voh.csv', 'w')
vohDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
vohDoc.write('\n')

transDoc = open('db/transport.csv', 'w')
transDoc.write('Email Address,Full Name,Contact(WhatsApp number),Contact 2(other number(s)),Programme of Study,Year,Name of Hostel,Hostel Location,Wing,Wing Executive,Specific Position,Old Shepherd,Motivation,Gender')
transDoc.write('\n')

bswList = []
organaList = []
evangList = []
coordiList = []
usherList = []
welfList = []
prayerList = []
rgcList = []
choirList = []
vohList = []
transList = []

for line in mainRef:
    modify_line = line.strip()
    
    if modify_line.split(',')[8] == 'Bible Study wing':
        if modify_line in bswList:
            continue
        else:
            bswDoc.write(modify_line)
            bswDoc.write('\n')
            bswList.append(modify_line)
        
    elif modify_line.split(',')[8] == 'Organizing wing':
        if modify_line in organaList:
            continue
        else:
            organaDoc.write(modify_line)
            organaDoc.write('\n')
            organaList.append(modify_line)
        
    elif modify_line.split(',')[8] == 'Royal Generation Choir':
        if modify_line in rgcList:
            continue
        else:
            rgcDoc.write(modify_line)
            rgcDoc.write('\n')
            rgcList.append(modify_line)

    elif modify_line.split(',')[8] == 'NUPS-G Choir':
        if modify_line in choirList:
            continue
        else:
            choirDoc.write(modify_line)
            choirDoc.write('\n')
            choirList.append(modify_line)
            
    elif modify_line.split(',')[8] == 'Welfare wing':
        if modify_line in welfList:
            continue
        else:
            welfDoc.write(modify_line)
            welfDoc.write('\n')
            welfList.append(modify_line)
            
    elif modify_line.split(',')[8] == 'Coordinating wing':
        if modify_line in coordiList:
            continue
        else:
            coordiDoc.write(modify_line)
            coordiDoc.write('\n')
            coordiList.append(modify_line)
            
    elif modify_line.split(',')[8] == 'Evangelism wing':
        if modify_line in evangList:
            continue
        else:
            evangDoc.write(modify_line)
            evangDoc.write('\n')
            evangList.append(modify_line)
            
    elif modify_line.split(',')[8] == 'Ushering wing':
        if modify_line in usherList:
            continue
        else:
            usherDoc.write(modify_line)
            usherDoc.write('\n')
            usherList.append(modify_line)
            
    elif modify_line.split(',')[8] == 'Vessels of Honor':
        if modify_line in vohList:
            continue
        else:
            vohDoc.write(modify_line)
            vohDoc.write('\n')
            vohList.append(modify_line)
            
    elif modify_line.split(',')[8] == 'Prayer wing':
        if modify_line in prayerList:
            continue
        else:
            prayerDoc.write(modify_line)
            prayerDoc.write('\n')
            prayerList.append(modify_line)
            
    elif modify_line.split(',')[8] == 'Transport wing':
        if modify_line in transList:
            continue
        else:
            transDoc.write(modify_line)
            transDoc.write('\n')
            transList.append(modify_line)

transDoc.close()
prayerDoc.close()
vohDoc.close()
usherDoc.close()
evangDoc.close()
coordiDoc.close()
welfDoc.close()
choirDoc.close()
rgcDoc.close()
organaDoc.close()
bswDoc.close()
openDoc.close()
